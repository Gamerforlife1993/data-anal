# %%
pip install pandas tabula-py PyPDF2
# Out:
# ...
#
# ...

# %%
pip install tabula-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
tabula-py PyPDF2

# %%
import tabula
import pandas as pd

# %%
# Path to your PDF file

# %%
pdf_path = "D:\Directory of Institution - University 05022024070841190PM.pdf"


dfs = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)
df=pd.concat(dfs)

# %%
df.shape

# %%
data_frame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data_frame
#
# NameError: name 'data_frame' is not defined

# %%
df
# Out:
#              State           District                    University Type  \
# 0                1                  2                                  3
# 1   Andhra Pradesh          Anantapur           State Private University
# 2   Andhra Pradesh          Anantapur                 Central University
# 3   Andhra Pradesh          Anantapur            State Public University
# 4   Andhra Pradesh          Anantapur            State Public University
# ..             ...                ...                                ...
# 10     West Bengal  Paschim Bardhaman            State Public University
# 11     West Bengal    Purba Bardhaman  Institute of National\rImportance
# 0                1                  2                                  3
# 1      West Bengal    Purba Bardhaman            State Public University
# 2      West Bengal            Purulia            State Public University
#
#                                       University Name  \
# ...

# %%
df1=df.copy()

# %%
df1
# Out:
#              State           District                    University Type  \
# 0                1                  2                                  3
# 1   Andhra Pradesh          Anantapur           State Private University
# 2   Andhra Pradesh          Anantapur                 Central University
# 3   Andhra Pradesh          Anantapur            State Public University
# 4   Andhra Pradesh          Anantapur            State Public University
# ..             ...                ...                                ...
# 10     West Bengal  Paschim Bardhaman            State Public University
# 11     West Bengal    Purba Bardhaman  Institute of National\rImportance
# 0                1                  2                                  3
# 1      West Bengal    Purba Bardhaman            State Public University
# 2      West Bengal            Purulia            State Public University
#
#                                       University Name  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5962 entries, 0 to 2
# Data columns (total 24 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               565 non-null    object
#  1   District                            565 non-null    object
#  2   University Type                     565 non-null    object
#  3   University Name                     565 non-null    object
#  4   Address                             526 non-null    object
#  5   Website                             523 non-null    object
# University       526 non-null    float64
#  7   Specialised in                      526 non-null    object
#  8   Location                            526 non-null    object
#  9   Upload Year                         565 non-null    object
# Survey Year  565 non-null    float64
#  11  Unnamed: 0                          784 non-null    object
# ...

# %%
df1.head(20)
# Out:
#              State       District                         University Type  \
# 0                1              2                                       3
# 1   Andhra Pradesh      Anantapur                State Private University
# 2   Andhra Pradesh      Anantapur                      Central University
# 3   Andhra Pradesh      Anantapur                 State Public University
# 4   Andhra Pradesh      Anantapur                 State Public University
# 5   Andhra Pradesh       Chittoor                 State Public University
# 6   Andhra Pradesh       Chittoor       Institute of National\rImportance
# 7   Andhra Pradesh       Chittoor       Institute of National\rImportance
# 8   Andhra Pradesh       Chittoor       Institute of National\rImportance
# 9   Andhra Pradesh       Chittoor                State Private University
# 10  Andhra Pradesh       Chittoor                      Central University
# 0                1              2                                       3
# ...

# %%
c=df1.drop(["Unnamed: 3","Unnamed: 4","Unnamed: 1","Unnamed: 2","Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8","Unnamed: 9","Unnamed: 10","Unnamed: 0","Unnamed: 11","Year When"],axis=1)

# %%
final_df=c.drop(0)

# %%
final_df
# Out:
#              State           District                    University Type  \
# 1   Andhra Pradesh          Anantapur           State Private University
# 2   Andhra Pradesh          Anantapur                 Central University
# 3   Andhra Pradesh          Anantapur            State Public University
# 4   Andhra Pradesh          Anantapur            State Public University
# 5   Andhra Pradesh           Chittoor            State Public University
# ..             ...                ...                                ...
# 9      West Bengal              Nadia            State Public University
# 10     West Bengal  Paschim Bardhaman            State Public University
# 11     West Bengal    Purba Bardhaman  Institute of National\rImportance
# 1      West Bengal    Purba Bardhaman            State Public University
# 2      West Bengal            Purulia            State Public University
#
#                                       University Name  \
# ...

# %%
final_df.shape
# Out:
# (5849, 11)

# %%
#correcting the format of the strings by omitting the "\r" present in them

# %%
exp_df=final_df.copy()

# %%
exp_df['University Name']=exp_df['University Name'].str.replace(r'\r',' ')
# Out:
# C:\Users\Sambit\AppData\Local\Temp\ipykernel_57584\2028143373.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   exp_df['University Name']=exp_df['University Name'].str.replace(r'\r',' ')

# %%
exp_df['Address']=exp_df['Address'].str.replace(r'\r',' ')
# Out:
# C:\Users\Sambit\AppData\Local\Temp\ipykernel_57584\799336338.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   exp_df['Address']=exp_df['Address'].str.replace(r'\r',' ')

# %%
exp_df
# Out:
#              State           District                    University Type  \
# 1   Andhra Pradesh          Anantapur           State Private University
# 2   Andhra Pradesh          Anantapur                 Central University
# 3   Andhra Pradesh          Anantapur            State Public University
# 4   Andhra Pradesh          Anantapur            State Public University
# 5   Andhra Pradesh           Chittoor            State Public University
# ..             ...                ...                                ...
# 9      West Bengal              Nadia            State Public University
# 10     West Bengal  Paschim Bardhaman            State Public University
# 11     West Bengal    Purba Bardhaman  Institute of National\rImportance
# 1      West Bengal    Purba Bardhaman            State Public University
# 2      West Bengal            Purulia            State Public University
#
#                                       University Name  \
# ...

# %%
exp_df.isnull().count()
# Out:
# State                                  5849
# District                               5849
# University Type                        5849
# University Name                        5849
# Address                                5849
# Website                                5849
# Year When\rDecalred\rUniversity        5849
# Specialised in                         5849
# Location                               5849
# Upload Year                            5849
# The Institute Added In\rSurvey Year    5849
# dtype: int64

# %%
#while loading the pdf file by concanteting due to some unseen error rows were multiplied with null values,so we drop all those row
# Out:
#   Cell In[86], line 2
#     where all the values are null
#           ^
# SyntaxError: invalid syntax

# %%
exp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5849 entries, 1 to 2
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               518 non-null    object
#  1   District                            518 non-null    object
#  2   University Type                     518 non-null    object
#  3   University Name                     518 non-null    object
#  4   Address                             479 non-null    object
#  5   Website                             476 non-null    object
# University       479 non-null    float64
#  7   Specialised in                      479 non-null    object
#  8   Location                            479 non-null    object
#  9   Upload Year                         518 non-null    object
# Survey Year  518 non-null    float64
# dtypes: float64(2), object(9)
# memory usage: 548.3+ KB

# %%
exp_df
# Out:
#              State           District                    University Type  \
# 1   Andhra Pradesh          Anantapur           State Private University
# 2   Andhra Pradesh          Anantapur                 Central University
# 3   Andhra Pradesh          Anantapur            State Public University
# 4   Andhra Pradesh          Anantapur            State Public University
# 5   Andhra Pradesh           Chittoor            State Public University
# ..             ...                ...                                ...
# 9      West Bengal              Nadia            State Public University
# 10     West Bengal  Paschim Bardhaman            State Public University
# 11     West Bengal    Purba Bardhaman  Institute of National\rImportance
# 1      West Bengal    Purba Bardhaman            State Public University
# 2      West Bengal            Purulia            State Public University
#
#                                       University Name  \
# ...

# %%
#finally our dataset is ready

# %%
exp_df.dropna(how='all',inplace=True)

# %%
exp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 518 entries, 1 to 2
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               518 non-null    object
#  1   District                            518 non-null    object
#  2   University Type                     518 non-null    object
#  3   University Name                     518 non-null    object
#  4   Address                             479 non-null    object
#  5   Website                             476 non-null    object
#  6   Year When Decalred University       479 non-null    float64
#  7   Specialised in                      479 non-null    object
#  8   Location                            479 non-null    object
#  9   Upload Year                         518 non-null    object
#  10  The Institute Added In Survey Year  518 non-null    float64
# dtypes: float64(2), object(9)
# ...

# %%
#null values present in "year when declared University","address","location","specialised in","website"

# %%
exp_df.rename(columns={'Year When\rDecalred\rUniversity': 'Year When Decalred University'}, inplace=True)

# %%
exp_df.rename(columns={'The Institute Added In\rSurvey Year': 'The Institute Added In Survey Year'}, inplace=True)
